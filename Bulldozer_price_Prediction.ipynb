# %% [markdown]
# <a href="https://colab.research.google.com/github/sethu-7/Bulldozer-Price-Prediction/blob/main/Bulldozer_price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv("/content/drive/MyDrive/bluebook-for-bulldozers/bluebook-for-bulldozers/TrainAndValid.csv",low_memory=False)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
fig,ax=plt.subplots()
ax.scatter(df['saledate'][:1000],df["SalePrice"][:1000])

# %%
df.SalePrice.hist()
# Out:
# <Axes: >

# %% [markdown]
# **Parsing dates**

# %%
df=pd.read_csv("/content/drive/MyDrive/bluebook-for-bulldozers/bluebook-for-bulldozers/TrainAndValid.csv",low_memory=False,parse_dates=["saledate"])

# %%
df.saledate.dtype
# Out:
# dtype('<M8[ns]')

# %%
fig,ax=plt.subplots()
ax.scatter(df['saledate'][:1000],df["SalePrice"][:1000])

# %% [markdown]
# **Sort dataframe in date order**

# %%
df_og=df.copy()
df_og
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 0       1139246    66000.0     999089     3157         121           3.0
# 1       1139248    57000.0     117657       77         121           3.0
# 2       1139249    10000.0     434808     7009         121           3.0
# 3       1139251    38500.0    1026470      332         121           3.0
# 4       1139253    11000.0    1057373    17311         121           3.0
# ...         ...        ...        ...      ...         ...           ...
# 412693  6333344    10000.0    1919201    21435         149           2.0
# 412694  6333345    10500.0    1882122    21436         149           2.0
# 412695  6333347    12500.0    1944213    21435         149           2.0
# 412696  6333348    10000.0    1794518    21435         149           2.0
# 412697  6333349    13000.0    1944743    21436         149           2.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# ...

# %%
df.sort_values(by=["saledate"],inplace=True,ascending=True)
df.saledate.head(10)
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
# 54653    1989-01-31
# 81383    1989-01-31
# 204924   1989-01-31
# 135376   1989-01-31
# 113390   1989-01-31
# Name: saledate, dtype: datetime64[ns]

# %%
df.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# 205615      1974                       NaN       NaN 1989-01-17  ...
# 274835      1980                       NaN       NaN 1989-01-31  ...
# 141296      1978                       NaN       NaN 1989-01-31  ...
# 212552      1980                       NaN       NaN 1989-01-31  ...
# 62755       1984                       NaN       NaN 1989-01-31  ...
#
#        Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# ...

# %%
df.saledate.dt.year
# Out:
# 205615    1989
# 274835    1989
# 141296    1989
# 212552    1989
# 62755     1989
#           ...
# 410879    2012
# 412476    2012
# 411927    2012
# 407124    2012
# 409203    2012
# Name: saledate, Length: 412698, dtype: int64

# %%
df['year']=df.saledate.dt.year
df['month']=df.saledate.dt.month
df['day']=df.saledate.dt.day

# %%
df.drop('saledate',axis=1)
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
# ...         ...        ...        ...      ...         ...           ...
# 410879  6302984    16000.0    1915521     5266         149          99.0
# 412476  6324811     6000.0    1919104    19330         149          99.0
# 411927  6313029    16000.0    1918416    17244         149          99.0
# 407124  6266251    55000.0     509560     3357         149          99.0
# 409203  6283635    34000.0    1869284     4701         149          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand fiModelDesc  ...  \
# ...

# %%
df.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'saledate', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc',
#        'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls', 'year',
#        'month', 'day'],
# ...

# %% [markdown]
# ##Modellling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 205615 to 409203
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  datetime64[ns]
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %% [markdown]
# See that all are in different dtype formats

# %%
for label,content in df.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
for label,content in df.items():
    if pd.api.types.is_string_dtype(content):
        df[label]=content.astype("category").cat.as_ordered()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 205615 to 409203
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   saledate                  412698 non-null  datetime64[ns]
#  10  fiModelDesc               412698 non-null  category
#  11  fiBaseModel               412698 non-null  category
#  12  fiSecondaryDesc           271971 non-null  category
# ...

# %%
for label,content in df.items():
    if pd.api.types.is_string_dtype(content):
        print(label)

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %% [markdown]
# **Fill missing values**

# %%
for label,content in df.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
for label,content in df.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
            df[label+'_is_missing']=pd.isnull(content)
            df[label]=content.fillna(content.median)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
for label,content in df.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)

# %%
for label,content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
        # if pd.isnull(content).sum():
        print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter
# UsageBand
# saledate
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
pd.Categorical(df['state']).codes
# Out:
# array([43,  8,  8, ...,  4,  4,  4], dtype=int8)

# %%
pd.Categorical(df['UsageBand']).codes
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int8)

# %%
for label,content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
        df[label+'_is_missing']=pd.isnull(content)
        df[label]=pd.Categorical(df[label]).codes+1;
        print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter
# UsageBand
# saledate
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
df.isna().sum()
# Out:
# SalesID                         0
# SalePrice                       0
# MachineID                       0
# ModelID                         0
# datasource                      0
#                                ..
# Backhoe_Mounting_is_missing     0
# Blade_Type_is_missing           0
# Travel_Controls_is_missing      0
# Differential_Type_is_missing    0
# Steering_Controls_is_missing    0
# Length: 103, dtype: int64

# %%
X=df.drop("SalePrice",axis=1)
Y=df["SalePrice"]

# %%
# %%time

rf=RandomForestRegressor(n_jobs=-1)
rf.fit(X,Y)
# Out:
# CPU times: user 20min, sys: 5.83 s, total: 20min 6s
# Wall time: 12min 22s
# RandomForestRegressor(n_jobs=-1)

# %%
rf.score(X,Y)
# Out:
# 0.9878320686651652

# %% [markdown]
# **This is not correct because the data has not been split**

# %% [markdown]
# ##Splitting data##

# %%
df_val=df[df.year==2012]
df_train=df[df.year!=2012]

# %%
x_train,y_train=df_train.drop('SalePrice',axis=1),df_train['SalePrice']
x_val,y_val=df_val.drop('SalePrice',axis=1),df_val['SalePrice']

x_train.shape,y_train.shape,x_val.shape,y_val.shape
# Out:
# ((401125, 102), (401125,), (11573, 102), (11573,))

# %% [markdown]
# ##Building our Evaluation Model##

# %% [markdown]
# **RMSLE :Root Mean Square Log Error**

# %%
from sklearn.metrics import mean_squared_log_error,mean_absolute_error,r2_score

def rmsle(y_test,y_preds):
    return np.sqrt(mean_squared_log_error(y_test,y_preds))


def show_scores(rf):
    train_preds=rf.predict(x_train)
    val_preds=rf.predict(x_val)
    scores={
        'train mae':mean_absolute_error(y_train,train_preds),
        'val mae':mean_absolute_error(y_val,val_preds),
        'train rmsle':rmsle(y_train,train_preds),
        'val rmsle':rmsle(y_val,val_preds),
        'train r_square':r2_score(y_train,train_preds),
        'val r_square':r2_score(y_val,val_preds)
    }
    return scores

# %%
# %%time
rf=RandomForestRegressor(n_jobs=-1,max_samples=1000)
rf.fit(x_train,y_train)
# Out:
# CPU times: user 5.12 s, sys: 827 ms, total: 5.94 s
# Wall time: 4.08 s
# RandomForestRegressor(max_samples=1000, n_jobs=-1)

# %%
show_scores(rf)
# Out:
# {'train mae': 7506.707809211592,
#  'val mae': 9396.758356519484,
#  'train rmsle': 0.33625965639915645,
#  'val rmsle': 0.38554092719658617,
#  'train r_square': 0.7636663610937858,
#  'val r_square': 0.7404697242760327}

# %% [markdown]
# ##Hyper parameter tuning##

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_grid={"n_estimators":np.arange(10,1000,50),"max_depth":[None,3,5,10],"min_samples_split":np.arange(2,20,2),"min_samples_leaf":np.arange(1,20,2),"max_samples":[1000],"max_features":[0.5,1,"sqrt",'auto']}

# %%
rf_log=RandomizedSearchCV(RandomForestRegressor(n_jobs=-1),param_distributions=rf_grid,cv=5,n_iter=5,verbose=True)

# %%
rf_log.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
rf_log.best_params_
# Out:
# {'n_estimators': 110,
#  'min_samples_split': 16,
#  'min_samples_leaf': 19,
#  'max_samples': 1000,
#  'max_features': 'auto',
#  'max_depth': None}

# %%
show_scores(rf_log)
# Out:
# {'train mae': 9042.273257572553,
#  'val mae': 10650.742261231424,
#  'train rmsle': 0.392450583229063,
#  'val rmsle': 0.41542263620231873,
#  'train r_square': 0.6643131995814676,
#  'val r_square': 0.650478962276277}

# %%
ideal_rf=RandomForestRegressor(n_estimators= 10,
 min_samples_split= 6,
 min_samples_leaf= 1,
 max_samples= None,
 max_features= 'auto',
 max_depth= 10,n_jobs=-1)

# %%
# %%time
ideal_rf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# CPU times: user 1min 6s, sys: 279 ms, total: 1min 6s
# Wall time: 40.6 s
# RandomForestRegressor(max_depth=10, max_features='auto', min_samples_split=6,
#                       n_estimators=10, n_jobs=-1)

# %%
show_scores(ideal_rf)
# Out:
# {'train mae': 6443.755943131482,
#  'val mae': 7743.609220274182,
#  'train rmsle': 0.292596027570489,
#  'val rmsle': 0.3125871157321397,
#  'train r_square': 0.8191685601420552,
#  'val r_square': 0.7971700407526129}

# %%
show_scores(rf)
# Out:
# {'train mae': 7506.707809211592,
#  'val mae': 9396.758356519484,
#  'train rmsle': 0.33625965639915645,
#  'val rmsle': 0.38554092719658617,
#  'train r_square': 0.7636663610937858,
#  'val r_square': 0.7404697242760327}

# %% [markdown]
# **Trying on test set**

# %%
df_test=pd.read_csv("/content/drive/MyDrive/bluebook-for-bulldozers/bluebook-for-bulldozers/Test.csv",low_memory=False,parse_dates=['saledate'])
df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# 0                    3688.0       Low 2012-05-03        580G  ...
# 1                   28555.0      High 2012-05-10         936  ...
# 2                    6038.0    Medium 2012-05-10    EC210BLC  ...
# 3                    8940.0      High 2012-05-10       330CL  ...
# 4                    2286.0       Low 2012-05-10        650K  ...
#
#   Undercarriage_Pad_Width         Stick_Length   Thumb      Pattern_Changer  \
# 0                     NaN                  NaN     NaN                  NaN
# ...

# %%
# test_preds=ideal_rf.predict(df_test)

# %%
def preprocess(df):
    df['year']=df.saledate.dt.year
    df['month']=df.saledate.dt.month
    df['day']=df.saledate.dt.day
    df.drop('saledate',axis=1)

    for label,content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                print(label)
                df[label+'_is_missing']=pd.isnull(content)
                df[label]=content.fillna(content.median)


    for label,content in df.items():
        if not pd.api.types.is_numeric_dtype(content):
            df[label+'_is_missing']=pd.isnull(content)
            df[label]=pd.Categorical(df[label]).codes+1;
            print(label)

    return df

# %%
df_test=preprocess(df_test)
# Out:
# MachineHoursCurrentMeter
# MachineHoursCurrentMeter
# UsageBand
# saledate
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  saledate  fiModelDesc  ...  \
# 0                         1          2         3          499  ...
# 1                         2          1         9          831  ...
# 2                         3          3         9         1177  ...
# 3                         4          1         9          287  ...
# 4                         5          2         9          566  ...
#
#    Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing  \
# 0                                True                     True
# ...

# %%
set(x_train.columns)-set(df_test.columns)
# Out:
# {'auctioneerID_is_missing'}

# %%
df_test['auctioneerID_is_missing']=False

# %%
df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  saledate  fiModelDesc  ...  \
# 0                         1          2         3          499  ...
# 1                         2          1         9          831  ...
# 2                         3          3         9         1177  ...
# 3                         4          1         9          287  ...
# 4                         5          2         9          566  ...
#
#    Thumb_is_missing  Pattern_Changer_is_missing  Grouser_Type_is_missing  \
# 0              True                        True                     True
# ...

# %%
df_test.drop('auctioneerrID_is_missing',axis=1)

# %%
test_preds=ideal_rf.predict(df_test)

# %%
def plot_features(columns,importances,n=20):
    df=(pd.DataFrame({"features":columns,"importances":importances}).sort_values('importances',ascending=True).reset_index(drop=True))

    fig,ax=plt.subplots()
    ax.barh(df['features'][:n],df[importances][:20])

# %%
plot_features(x_train.columns,ideal_rf.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-249-c4ef521b13b6> in <cell line: 1>()
# ----> 1 plot_features(x_train.columns,ideal_rf.feature_importances_)
#
# <ipython-input-248-05e30b925b7b> in plot_features(columns, importances, n)
#       3
#       4     fig,ax=plt.subplots()
# ----> 5     ax.barh(df['features'][:n],df[importances][:20])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
def plot_features(columns, importances, n=20):
    df = (pd.DataFrame({"features": columns, "importances": importances}).sort_values('importances', ascending=False).reset_index(drop=True))

    fig, ax = plt.subplots()
    ax.barh(df['features'][20:], df['importances'][20:])  # Fix here

# Assuming x_train is your training data and ideal_rf is your RandomForest model
plot_features(x_train.columns, ideal_rf.feature_importances_)
